# %% [markdown]
# <a href="https://colab.research.google.com/github/isj0/DataAnalysis-Python/blob/main/Modifying_DataFrames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

houses = pd.read_csv("/content/drive/MyDrive/DataAnalysis/data/kc_house_data.csv")
titanic = pd.read_csv("/content/drive/MyDrive/DataAnalysis/data/titanic.csv")
netflix = pd.read_csv("/content/drive/MyDrive/DataAnalysis/data/netflix_titles.csv", sep="|")
btc = pd.read_csv("/content/drive/MyDrive/DataAnalysis/data/coin_Bitcoin.csv")
countries = pd.read_csv("/content/drive/MyDrive/DataAnalysis/data/world-happiness-report-2021.csv")

# %%
countries.set_index("Country name", inplace=True)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
countries.head(3)
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Finland          Western Europe         7.842                           0.032
# Denmark          Western Europe         7.620                           0.035
# Switzerland      Western Europe         7.571                           0.036
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Finland              7.904         7.780                 10.775
# Denmark              7.687         7.552                 10.933
# Switzerland          7.643         7.500                 11.117
#
#               Social support  Healthy life expectancy  \
# Country name
# Finland                0.954                     72.0
# Denmark                0.954                     72.7
# Switzerland            0.942                     74.4
#
#               Freedom to make life choices  Generosity  \
# Country name
# Finland                              0.949      -0.098
# ...

# %%
btc.head(3)
# Out:
#    SNo     Name Symbol                 Date        High         Low     Open  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000  134.444
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003  144.000
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001  139.000
#
#         Close  Volume     Marketcap
# 0  144.539993     0.0  1.603769e+09
# 1  139.000000     0.0  1.542813e+09
# 2  116.989998     0.0  1.298955e+09

# %% [markdown]
# ## Dropping Rows & Columns

# %%
btc.drop(labels=["Symbol", "Name", "SNo"], axis=1)
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
btc.drop(labels=["Symbol", "Name"], axis="columns")
# Out:
#        SNo                 Date          High           Low          Open  \
# 0        1  2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1        2  2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2        3  2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3        4  2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4        5  2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...    ...                  ...           ...           ...           ...
# 2986  2987  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2988  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2989  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2990  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2991  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# ...

# %%
btc.drop(columns=["Name", "Symbol"])
# Out:
#        SNo                 Date          High           Low          Open  \
# 0        1  2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1        2  2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2        3  2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3        4  2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4        5  2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...    ...                  ...           ...           ...           ...
# 2986  2987  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2988  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2989  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2990  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2991  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# ...

# %%
df_btc = btc[["Date", "High", "Low"]]

# %%
df_btc.head()
# Out:
#                   Date        High         Low
# 0  2013-04-29 23:59:59  147.488007  134.000000
# 1  2013-04-30 23:59:59  146.929993  134.050003
# 2  2013-05-01 23:59:59  139.889999  107.720001
# 3  2013-05-02 23:59:59  125.599998   92.281898
# 4  2013-05-03 23:59:59  108.127998   79.099998

# %%
countries.drop(labels="Denmark", axis=0)
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries.drop(["Denmark", "Iceland", "Finland"])
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Switzerland       Western Europe         7.571
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# Sweden            Western Europe         7.363
# Luxembourg        Western Europe         7.324
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Switzerland                            0.036         7.643         7.500
# Netherlands                            0.027         7.518         7.410
# Norway                                 0.035         7.462         7.323
# ...

# %%
btc.sort_index(ascending=False, inplace=True)

# %%
btc.head()
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
#
#               Open         Close        Volume     Marketcap
# 2990  33723.509655  34235.193451  2.650126e+10  6.418992e+11
# 2989  35284.344430  33746.002456  2.672155e+10  6.326962e+11
# 2988  34665.564866  35287.779766  2.492431e+10  6.615748e+11
# 2987  33854.421362  34668.548402  2.438396e+10  6.499397e+11
# 2986  33549.600177  33897.048590  3.872897e+10  6.354508e+11

# %%
btc.drop(2990)
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2985  2986  Bitcoin    BTC  2021-07-01 23:59:59  35035.982712  32883.781226
# ...    ...      ...    ...                  ...           ...           ...
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
#
# ...

# %%
countries.drop(countries.index[0:3])
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# Sweden            Western Europe         7.363
# Luxembourg        Western Europe         7.324
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Iceland                                0.059         7.670         7.438
# Netherlands                            0.027         7.518         7.410
# Norway                                 0.035         7.462         7.323
# ...

# %%
countries.drop(countries.index[10:])
# Out:
#                  Regional indicator  Ladder score  \
# Country name
# Finland              Western Europe         7.842
# Denmark              Western Europe         7.620
# Switzerland          Western Europe         7.571
# Iceland              Western Europe         7.554
# Netherlands          Western Europe         7.464
# Norway               Western Europe         7.392
# Sweden               Western Europe         7.363
# Luxembourg           Western Europe         7.324
# New Zealand   North America and ANZ         7.277
# Austria              Western Europe         7.268
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %% [markdown]
# ## Adding Rows & Columns

# %%
titanic["species"] = "human"

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest species
# ...

# %%
houses.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
houses.insert(0, "county", "King County")

# %%
houses.head()
# Out:
#         county          id             date     price  bedrooms  bathrooms  \
# 0  King County  7129300520  20141013T000000  221900.0         3       1.00
# 1  King County  6414100192  20141209T000000  538000.0         3       2.25
# 2  King County  5631500400  20150225T000000  180000.0         2       1.00
# 3  King County  2487200875  20141209T000000  604000.0         4       3.00
# 4  King County  1954400510  20150218T000000  510000.0         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
houses["sale_price"] = houses["price"] / 10

# %%
houses.head()
# Out:
#         county          id             date     price  bedrooms  bathrooms  \
# 0  King County  7129300520  20141013T000000  221900.0         3       1.00
# 1  King County  6414100192  20141209T000000  538000.0         3       2.25
# 2  King County  5631500400  20150225T000000  180000.0         2       1.00
# 3  King County  2487200875  20141209T000000  604000.0         4       3.00
# 4  King County  1954400510  20150218T000000  510000.0         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  sqft_above  sqft_basement  \
# 0         1180      5650     1.0           0  ...        1180              0
# 1         2570      7242     2.0           0  ...        2170            400
# 2          770     10000     1.0           0  ...         770              0
# 3         1960      5000     1.0           0  ...        1050            910
# 4         1680      8080     1.0           0  ...        1680              0
#
# ...

# %%
houses.insert(3, "num_beds", houses["bedrooms"])

# %%
houses.head()
# Out:
#         county          id             date  num_beds     price  bedrooms  \
# 0  King County  7129300520  20141013T000000         3  221900.0         3
# 1  King County  6414100192  20141209T000000         3  538000.0         3
# 2  King County  5631500400  20150225T000000         2  180000.0         2
# 3  King County  2487200875  20141209T000000         4  604000.0         4
# 4  King County  1954400510  20150218T000000         3  510000.0         3
#
#    bathrooms  sqft_living  sqft_lot  floors  ...  sqft_above  sqft_basement  \
# 0       1.00         1180      5650     1.0  ...        1180              0
# 1       2.25         2570      7242     2.0  ...        2170            400
# 2       1.00          770     10000     1.0  ...         770              0
# 3       3.00         1960      5000     1.0  ...        1050            910
# 4       2.00         1680      8080     1.0  ...        1680              0
#
# ...

# %%
titanic.drop(columns=["species"], inplace=True)

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic["parch"]
# Out:
# 0       0
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: parch, Length: 1309, dtype: int64

# %%
titanic["sibsp"]
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Name: sibsp, Length: 1309, dtype: int64

# %%
titanic["num_relatives"] = titanic["parch"] + titanic["sibsp"]

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest  num_relatives
# ...

# %%
titanic.sort_values("num_relatives", ascending=False)
# Out:
#       pclass  survived                                    name     sex age  \
# 1177       3         0                     Sage, Mr. Frederick    male   ?
# 1179       3         0                   Sage, Mr. John George    male   ?
# 1173       3         0            Sage, Miss. Constance Gladys  female   ?
# 1170       3         0              Sage, Master. Thomas Henry    male   ?
# 1172       3         0                         Sage, Miss. Ada  female   ?
# ...      ...       ...                                     ...     ...  ..
# 598        2         1                    Wright, Miss. Marion  female  26
# 599        2         0  Yrois, Miss. Henriette ('Mrs Harbeck')  female  24
# 600        3         0                     Abbing, Mr. Anthony    male  42
# 604        3         1             Abelseth, Miss. Karen Marie  female  16
# 1308       3         0                      Zimmerman, Mr. Leo    male  29
#
#       sibsp  parch     ticket   fare cabin embarked boat body  \
# ...

# %%
titanic[titanic['survived'] == 1].sort_values("num_relatives", ascending=False)
# Out:
#      pclass  survived                                               name  \
# 641       3         1                  Asplund, Master. Edvin Rojj Felix
# 625       3         1                    Andersson, Miss. Erna Alexandra
# 646       3         1  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 643       3         1                     Asplund, Miss. Lillian Gertrud
# 111       1         1                     Fortune, Miss. Alice Elizabeth
# ..      ...       ...                                                ...
# 597       2         1                       Williams, Mr. Charles Eugene
# 598       2         1                               Wright, Miss. Marion
# 604       3         1                        Abelseth, Miss. Karen Marie
# 605       3         1                      Abelseth, Mr. Olaus Jorgensen
# 0         1         1                      Allen, Miss. Elisabeth Walton
#
#         sex age  sibsp  parch   ticket      fare        cabin embarked boat  \
# ...

# %%
solo_passengers = titanic["num_relatives"] == 0
titanic[solo_passengers]
# Out:
#       pclass  survived                           name     sex   age  sibsp  \
# 0          1         1  Allen, Miss. Elisabeth Walton  female    29      0
# 5          1         1            Anderson, Mr. Harry    male    48      0
# 7          1         0         Andrews, Mr. Thomas Jr    male    39      0
# 9          1         0        Artagaveytia, Mr. Ramon    male    71      0
# 12         1         1  Aubart, Mme. Leontine Pauline  female    24      0
# ...      ...       ...                            ...     ...   ...    ...
# 1302       3         0              Yousif, Mr. Wazli    male     ?      0
# 1303       3         0          Yousseff, Mr. Gerious    male     ?      0
# 1306       3         0      Zakarian, Mr. Mapriededer    male  26.5      0
# 1307       3         0            Zakarian, Mr. Ortin    male    27      0
# 1308       3         0             Zimmerman, Mr. Leo    male    29      0
#
# ...

# %%
titanic[solo_passengers].pclass.value_counts()
# Out:
# pclass
# 3    472
# 1    160
# 2    158
# Name: count, dtype: int64

# %%
titanic.pclass.value_counts()
# Out:
# pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
titanic.sex.value_counts()
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
titanic[solo_passengers].sex.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
houses.head()
# Out:
#         county          id             date  num_beds     price  bedrooms  \
# 0  King County  7129300520  20141013T000000         3  221900.0         3
# 1  King County  6414100192  20141209T000000         3  538000.0         3
# 2  King County  5631500400  20150225T000000         2  180000.0         2
# 3  King County  2487200875  20141209T000000         4  604000.0         4
# 4  King County  1954400510  20150218T000000         3  510000.0         3
#
#    bathrooms  sqft_living  sqft_lot  floors  ...  sqft_above  sqft_basement  \
# 0       1.00         1180      5650     1.0  ...        1180              0
# 1       2.25         2570      7242     2.0  ...        2170            400
# 2       1.00          770     10000     1.0  ...         770              0
# 3       3.00         1960      5000     1.0  ...        1050            910
# 4       2.00         1680      8080     1.0  ...        1680              0
#
# ...

# %%
houses["price_sqft"] = houses["price"] / houses["sqft_living"]

# %%
houses.head()
# Out:
#         county          id             date  num_beds     price  bedrooms  \
# 0  King County  7129300520  20141013T000000         3  221900.0         3
# 1  King County  6414100192  20141209T000000         3  538000.0         3
# 2  King County  5631500400  20150225T000000         2  180000.0         2
# 3  King County  2487200875  20141209T000000         4  604000.0         4
# 4  King County  1954400510  20150218T000000         3  510000.0         3
#
#    bathrooms  sqft_living  sqft_lot  floors  ...  sqft_basement  yr_built  \
# 0       1.00         1180      5650     1.0  ...              0      1955
# 1       2.25         2570      7242     2.0  ...            400      1951
# 2       1.00          770     10000     1.0  ...              0      1933
# 3       3.00         1960      5000     1.0  ...            910      1965
# 4       2.00         1680      8080     1.0  ...              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
houses.sort_values("price_sqft", ascending=False)
# Out:
#             county          id             date  num_beds      price  \
# 19336  King County  6021500970  20150407T000000         2   874950.0
# 4013   King County   724069059  20140509T000000         3  2400000.0
# 10446  King County  1118000320  20150508T000000         4  3400000.0
# 8623   King County  6303400395  20150130T000000         1   325000.0
# 9314   King County  4389200610  20141201T000000         2   903000.0
# ...            ...         ...              ...       ...        ...
# 1385   King County  3342700465  20150123T000000         3   250000.0
# 17197  King County  5111400086  20140512T000000         3   110000.0
# 13825  King County  5637200450  20141017T000000         5   257000.0
# 3785   King County   723049156  20140523T000000         3   149000.0
# 18262  King County  2891000610  20141211T000000         4   148900.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_basement  \
# ...

# %%
houses.sort_values("price_sqft", ascending=False).head(50)["zipcode"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='zipcode'>

# %%
btc.head()
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
#
#               Open         Close        Volume     Marketcap
# 2990  33723.509655  34235.193451  2.650126e+10  6.418992e+11
# 2989  35284.344430  33746.002456  2.672155e+10  6.326962e+11
# 2988  34665.564866  35287.779766  2.492431e+10  6.615748e+11
# 2987  33854.421362  34668.548402  2.438396e+10  6.499397e+11
# 2986  33549.600177  33897.048590  3.872897e+10  6.354508e+11

# %%
btc.set_index("Date")
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2021-07-06 23:59:59  2991  Bitcoin    BTC  35038.536363  33599.916169
# 2021-07-05 23:59:59  2990  Bitcoin    BTC  35284.344430  33213.661034
# 2021-07-04 23:59:59  2989  Bitcoin    BTC  35937.567147  34396.477458
# 2021-07-03 23:59:59  2988  Bitcoin    BTC  34909.259899  33402.696536
# 2021-07-02 23:59:59  2987  Bitcoin    BTC  33939.588699  32770.680780
# ...                   ...      ...    ...           ...           ...
# 2013-05-03 23:59:59     5  Bitcoin    BTC    108.127998     79.099998
# 2013-05-02 23:59:59     4  Bitcoin    BTC    125.599998     92.281898
# 2013-05-01 23:59:59     3  Bitcoin    BTC    139.889999    107.720001
# 2013-04-30 23:59:59     2  Bitcoin    BTC    146.929993    134.050003
# 2013-04-29 23:59:59     1  Bitcoin    BTC    147.488007    134.000000
#
#                              Open         Close        Volume     Marketcap
# Date
# ...

# %%
btc["change"] = btc["Close"] - btc["Open"]

# %%
btc.head()
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
#
#               Open         Close        Volume     Marketcap       change
# 2990  33723.509655  34235.193451  2.650126e+10  6.418992e+11   511.683796
# 2989  35284.344430  33746.002456  2.672155e+10  6.326962e+11 -1538.341974
# 2988  34665.564866  35287.779766  2.492431e+10  6.615748e+11   622.214900
# 2987  33854.421362  34668.548402  2.438396e+10  6.499397e+11   814.127040
# 2986  33549.600177  33897.048590  3.872897e+10  6.354508e+11   347.448412

# %%
btc.sort_values("change", ascending=False)
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 2842  2843  Bitcoin    BTC  2021-02-08 23:59:59  46203.931437  38076.322807
# 2919  2920  Bitcoin    BTC  2021-04-26 23:59:59  54288.002155  48852.796843
# 2863  2864  Bitcoin    BTC  2021-03-01 23:59:59  49784.015290  45115.093115
# 2853  2854  Bitcoin    BTC  2021-02-19 23:59:59  56113.650547  50937.275722
# 2923  2924  Bitcoin    BTC  2021-04-30 23:59:59  57900.719988  53129.600877
# ...    ...      ...    ...                  ...           ...           ...
# 2911  2912  Bitcoin    BTC  2021-04-18 23:59:59  61057.456509  52829.535926
# 2824  2825  Bitcoin    BTC  2021-01-21 23:59:59  35552.679497  30250.749639
# 2857  2858  Bitcoin    BTC  2021-02-23 23:59:59  54204.929756  45290.590268
# 2942  2943  Bitcoin    BTC  2021-05-19 23:59:59  43546.116485  30681.496912
# 2935  2936  Bitcoin    BTC  2021-05-12 23:59:59  57939.362415  49150.533875
#
# ...

# %%
btc["delta"] = btc["High"] - btc["Low"]

# %%
btc.sort_values("delta", ascending=False)
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 2942  2943  Bitcoin    BTC  2021-05-19 23:59:59  43546.116485  30681.496912
# 2857  2858  Bitcoin    BTC  2021-02-23 23:59:59  54204.929756  45290.590268
# 2935  2936  Bitcoin    BTC  2021-05-12 23:59:59  57939.362415  49150.533875
# 2856  2857  Bitcoin    BTC  2021-02-22 23:59:59  57533.389325  48967.565188
# 2944  2945  Bitcoin    BTC  2021-05-21 23:59:59  42172.173616  33616.453884
# ...    ...      ...    ...                  ...           ...           ...
# 871    872  Bitcoin    BTC  2015-09-17 23:59:59    230.285004    228.925995
# 768    769  Bitcoin    BTC  2015-06-06 23:59:59    225.718994    224.378998
# 759    760  Bitcoin    BTC  2015-05-28 23:59:59    237.824005    236.651993
# 888    889  Bitcoin    BTC  2015-10-04 23:59:59    238.968002    237.940002
# 100    101  Bitcoin    BTC  2013-08-07 23:59:59    106.750000    106.750000
#
# ...

# %%
btc.set_index("Date")
btc.sort_values("delta", ascending=False).head(10)["delta"].plot(kind="bar")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-f2ee5510a93e> in <cell line: 1>()
# ----> 1 btc.set_index("Date")
#       2 btc.sort_values("delta", ascending=False).head(10)["delta"].plot(kind="bar")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5868
#    5869         if missing:
# -> 5870             raise KeyError(f"None of {missing} are in the columns")
#    5871
#    5872         if inplace:
#
# KeyError: "None of ['Date'] are in the columns"

# %%
btc.sort_values("delta", ascending=False).head(10)["delta"].plot(kind="bar")
# Out:
# <Axes: xlabel='Date'>
